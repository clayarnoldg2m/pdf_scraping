# %%
import os
import json
import pandas as pd
import pdfplumber
import re
from datetime import datetime

class QuestionnairePDFExtractor:
    """Class to extract questions and answers from questionnaire PDFs"""
    
    def __init__(self, output_dir=None):
        """Initialize the extractor with an optional output directory"""
        self.output_dir = output_dir
    
    def extract_questions_from_pdf(self, pdf_file):
        """Extract questions and answers from PDF"""
        print(f"Extracting questionnaire content from: {pdf_file}")
        questions_data = []
        
        try:
            with pdfplumber.open(pdf_file) as pdf:
                for page_num, page in enumerate(pdf.pages):
                    print(f"Processing page {page_num+1} of {len(pdf.pages)}")
                    
                    # Extract text for question detection
                    text = page.extract_text()
                    
                    # Look for question patterns
                    question_pattern = re.compile(r'^\(?\d+\.?\d*\)?\s+(.+?)$', re.MULTILINE)
                    form_field_pattern = re.compile(r'(.+?):\s*$', re.MULTILINE)
                    checkbox_pattern = re.compile(r'[☐☑✓]|•\s')
                    
                    # Extract tables
                    tables = page.extract_tables()
                    
                    # Find questions in text
                    questions_in_text = []
                    for match in question_pattern.finditer(text):
                        question_text = match.group(1).strip()
                        if '?' in question_text:  # Likely a question
                            questions_in_text.append({
                                'page': page_num + 1,
                                'question_text': question_text,
                                'position': match.start(),
                                'type': 'numbered_question'
                            })
                    
                    # Find form fields
                    for match in form_field_pattern.finditer(text):
                        field_text = match.group(1).strip()
                        if len(field_text) > 5:  # Avoid small fragments
                            questions_in_text.append({
                                'page': page_num + 1,
                                'question_text': field_text,
                                'position': match.start(),
                                'type': 'form_field'
                            })
                    
                    # Process extracted tables to find question-answer pairs
                    for table_num, table in enumerate(tables):
                        df = pd.DataFrame(table)
                        
                        # Clean DataFrame
                        for col in df.columns:
                            df[col] = df[col].map(lambda x: str(x).strip() if x is not None else "", na_action='ignore')
                        
                        # Fill NaN values
                        df = df.fillna("")
                        
                        # Try to identify if this is a question-answer table
                        question_columns = []
                        answer_columns = []
                        
                        # Check each column to see if it contains questions or answers
                        for col in df.columns:
                            col_values = df[col].astype(str).tolist()
                            # Check if this looks like a question column
                            if any('?' in val for val in col_values) or any(re.match(r'^\d+\.', val) for val in col_values):
                                question_columns.append(col)
                            # Check if this looks like an answer column
                            elif any(checkbox_pattern.search(val) for val in col_values) or any(val.startswith('□') for val in col_values):
                                answer_columns.append(col)
                        
                        # If we have identified question-answer structure
                        if question_columns or answer_columns:
                            # Convert to question-answer format
                            for i, row in df.iterrows():
                                # Skip empty rows
                                if all(str(cell).strip() == "" for cell in row):
                                    continue
                                
                                # Extract question and answer
                                question_text = ""
                                if question_columns:
                                    question_text = " ".join([str(row[col]) for col in question_columns if str(row[col]).strip()])
                                else:
                                    # Try to get question from text nearby
                                    # This is approximate - might need position analysis for better accuracy
                                    question_text = f"Table {table_num+1} Row {i+1}"
                                
                                answer_data = {}
                                for col in answer_columns:
                                    answer_data[str(col)] = str(row[col])
                                
                                if not question_columns and not answer_columns:
                                    # This might be a data table, include all columns
                                    for col in df.columns:
                                        answer_data[str(col)] = str(row[col])
                                
                                # Only add if we have some content
                                if question_text.strip() or any(ans.strip() for ans in answer_data.values()):
                                    questions_data.append({
                                        'page': page_num + 1,
                                        'question_text': question_text,
                                        'answer_data': answer_data,
                                        'type': 'table_question',
                                        'table_num': table_num + 1
                                    })
                                    
                    # Add questions found in text (not in tables)
                    for question in questions_in_text:
                        # Check if we already have this from a table
                        if not any(q.get('question_text') == question['question_text'] for q in questions_data):
                            questions_data.append(question)
            
            # Sort all questions by page and position/table_num
            questions_data.sort(key=lambda x: (x['page'], x.get('position', 0) if 'position' in x else x.get('table_num', 0)))
            
            return questions_data
        
        except Exception as e:
            print(f"Error extracting questionnaire content: {str(e)}")
            return []
    
    def detect_question_type(self, question_data):
        """Detect the type of question based on answer format"""
        if 'answer_data' not in question_data:
            return 'text_question'
            
        answer_data = question_data['answer_data']
        
        # Check for checkboxes or multiple choice
        checkbox_pattern = re.compile(r'[☐☑✓]|•\s')
        has_checkbox = any(checkbox_pattern.search(str(ans)) for ans in answer_data.values())
        
        if has_checkbox:
            return 'multiple_choice'
        
        # Check for dropdown/select
        if len(answer_data) == 1 and any(str(ans).startswith('Select') for ans in answer_data.values()):
            return 'dropdown'
            
        # Check for text field
        if len(answer_data) == 1 and any('characters' in str(ans).lower() for ans in answer_data.values()):
            return 'text_field'
            
        return 'general_question'
    
    def process_and_merge_related_questions(self, questions_data):
        """Merge related questions and organize into a clearer structure"""
        merged_questions = []
        current_section = None
        i = 0
        
        while i < len(questions_data):
            question = questions_data[i]
            
            # Check if this is a section header
            if 'question_text' in question and re.match(r'^[A-Z0-9\.\s]+$', question['question_text']) and len(question['question_text']) < 50:
                current_section = question['question_text']
                i += 1
                continue
                
            # Check for multi-part questions (questions with options)
            if i < len(questions_data) - 1:
                next_question = questions_data[i + 1]
                
                # If the next question is on the same page and has options
                if (next_question['page'] == question['page'] and 
                    'type' in next_question and next_question['type'] == 'table_question' and
                    'table_num' in next_question):
                    
                    # Check if they look related
                    if 'answer_data' not in question or not question['answer_data']:
                        # Merge them
                        new_question = question.copy()
                        new_question['options'] = next_question.get('answer_data', {})
                        new_question['type'] = self.detect_question_type(next_question)
                        
                        merged_questions.append(new_question)
                        i += 2  # Skip both questions
                        continue
            
            # Add question type if not already set
            if 'type' not in question or question['type'] in ['form_field', 'numbered_question']:
                question['type'] = self.detect_question_type(question)
                
            # Add section info
            if current_section:
                question['section'] = current_section
                
            merged_questions.append(question)
            i += 1
            
        return merged_questions
    
    def convert_to_json(self, pdf_file, save_output=True):
        """Process a PDF questionnaire and convert to structured JSON"""
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        base_filename = os.path.splitext(os.path.basename(pdf_file))[0]
        
        # Create output directory if needed
        if self.output_dir and not os.path.exists(self.output_dir):
            os.makedirs(self.output_dir)
        
        # Extract questions and answers
        questions_data = self.extract_questions_from_pdf(pdf_file)
        
        # Process and merge related questions
        processed_questions = self.process_and_merge_related_questions(questions_data)
        
        # Create JSON structure
        json_data = {
            "document": {
                "filename": os.path.basename(pdf_file),
                "extraction_date": datetime.now().isoformat(),
                "questions": processed_questions
            }
        }
        
        # Save JSON file
        if save_output and self.output_dir:
            json_file = os.path.join(self.output_dir, f"{base_filename}_questionnaire_{timestamp}.json")
            with open(json_file, 'w', encoding='utf-8') as f:
                json.dump(json_data, f, indent=2, ensure_ascii=False)
            print(f"\nJSON output saved to: {json_file}")
        
        return json_data

# Example usage
if __name__ == "__main__":
    # Path to your PDF
    pdf_file = r'pdf_files\CDP_2024_Corporate_Questionnaire_Guidance_Modules_1-6.pdf'
    
    # Create output directory
    output_dir = "pdf_extractions"
    os.makedirs(output_dir, exist_ok=True)
    
    # Initialize extractor
    extractor = QuestionnairePDFExtractor(output_dir=output_dir)
    
    # Convert PDF to JSON
    result = extractor.convert_to_json(pdf_file)
    
    # Print summary
    print(f"\nExtraction complete!")
    print(f"Found {len(result['document']['questions'])} questions and response items")
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Extracting questionnaire content from: pdf_files\CDP_2024_Corporate_Questionnaire_Guidance_Modules_1-6.pdf
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Processing page 1 of 368
# Processing page 2 of 368
# Processing page 3 of 368
# Processing page 4 of 368
# Processing page 5 of 368
# Processing page 6 of 368
# Processing page 7 of 368
# Processing page 8 of 368
# Processing page 9 of 368
# Processing page 10 of 368
# Processing page 11 of 368
# Processing page 12 of 368
# Processing page 13 of 368
# Processing page 14 of 368
# Processing page 15 of 368
# Processing page 16 of 368
# Processing page 17 of 368
# Processing page 18 of 368
# Processing page 19 of 368
# Processing page 20 of 368
# Processing page 21 of 368
# Processing page 22 of 368
# Processing page 23 of 368
# Processing page 24 of 368
# Processing page 25 of 368
# Processing page 26 of 368
# Processing page 27 of 368
# Processing page 28 of 368
# Processing page 29 of 368
# Processing page 30 of 368
# Processing page 31 of 368
# Processing page 32 of 368
# Processing page 33 of 368
# Processing page 34 of 368
# Processing page 35 of 368
# Processing page 36 of 368
# Processing page 37 of 368
# Processing page 38 of 368
# Processing page 39 of 368
# Processing page 40 of 368
# Processing page 41 of 368
# Processing page 42 of 368
# Processing page 43 of 368
# Processing page 44 of 368
# Processing page 45 of 368
# Processing page 46 of 368
# Processing page 47 of 368
# Processing page 48 of 368
# Processing page 49 of 368
# Processing page 50 of 368
# Processing page 51 of 368
# Processing page 52 of 368
# Processing page 53 of 368
# Processing page 54 of 368
# Processing page 55 of 368
# Processing page 56 of 368
# Processing page 57 of 368
# Processing page 58 of 368
# Processing page 59 of 368
# Processing page 60 of 368
# Processing page 61 of 368
# Processing page 62 of 368
# Processing page 63 of 368
# Processing page 64 of 368
# Processing page 65 of 368
# Processing page 66 of 368
# Processing page 67 of 368
# Processing page 68 of 368
# Processing page 69 of 368
# Processing page 70 of 368
# Processing page 71 of 368
# Processing page 72 of 368
# Processing page 73 of 368
# Processing page 74 of 368
# Processing page 75 of 368
# Processing page 76 of 368
# Processing page 77 of 368
# Processing page 78 of 368
# Processing page 79 of 368
# Processing page 80 of 368
# Processing page 81 of 368
# Processing page 82 of 368
# Processing page 83 of 368
# Processing page 84 of 368
# Processing page 85 of 368
# Processing page 86 of 368
# Processing page 87 of 368
# Processing page 88 of 368
# Processing page 89 of 368
# Processing page 90 of 368
# Processing page 91 of 368
# Processing page 92 of 368
# Processing page 93 of 368
# Processing page 94 of 368
# Processing page 95 of 368
# Processing page 96 of 368
# Processing page 97 of 368
# Processing page 98 of 368
# Processing page 99 of 368
# Processing page 100 of 368
# Processing page 101 of 368
# Processing page 102 of 368
# Processing page 103 of 368
# Processing page 104 of 368
# Processing page 105 of 368
# Processing page 106 of 368
# Processing page 107 of 368
# Processing page 108 of 368
# Processing page 109 of 368
# Processing page 110 of 368
# Processing page 111 of 368
# Processing page 112 of 368
# Processing page 113 of 368
# Processing page 114 of 368
# Processing page 115 of 368
# Processing page 116 of 368
# Processing page 117 of 368
# Processing page 118 of 368
# Processing page 119 of 368
# Processing page 120 of 368
# Processing page 121 of 368
# Processing page 122 of 368
# Processing page 123 of 368
# Processing page 124 of 368
# Processing page 125 of 368
# Processing page 126 of 368
# Processing page 127 of 368
# Processing page 128 of 368
# Processing page 129 of 368
# Processing page 130 of 368
# Processing page 131 of 368
# Processing page 132 of 368
# Processing page 133 of 368
# Processing page 134 of 368
# Processing page 135 of 368
# Processing page 136 of 368
# Processing page 137 of 368
# Processing page 138 of 368
# Processing page 139 of 368
# Processing page 140 of 368
# Processing page 141 of 368
# Processing page 142 of 368
# Processing page 143 of 368
# Processing page 144 of 368
# Processing page 145 of 368
# Processing page 146 of 368
# Processing page 147 of 368
# Processing page 148 of 368
# Processing page 149 of 368
# Processing page 150 of 368
# Processing page 151 of 368
# Processing page 152 of 368
# Processing page 153 of 368
# Processing page 154 of 368
# Processing page 155 of 368
# Processing page 156 of 368
# Processing page 157 of 368
# Processing page 158 of 368
# Processing page 159 of 368
# Processing page 160 of 368
# Processing page 161 of 368
# Processing page 162 of 368
# Processing page 163 of 368
# Processing page 164 of 368
# Processing page 165 of 368
# Processing page 166 of 368
# Processing page 167 of 368
# Processing page 168 of 368
# Processing page 169 of 368
# Processing page 170 of 368
# Processing page 171 of 368
# Processing page 172 of 368
# Processing page 173 of 368
# Processing page 174 of 368
# Processing page 175 of 368
# Processing page 176 of 368
# Processing page 177 of 368
# Processing page 178 of 368
# Processing page 179 of 368
# Processing page 180 of 368
# Processing page 181 of 368
# Processing page 182 of 368
# Processing page 183 of 368
# Processing page 184 of 368
# Processing page 185 of 368
# Processing page 186 of 368
# Processing page 187 of 368
# Processing page 188 of 368
# Processing page 189 of 368
# Processing page 190 of 368
# Processing page 191 of 368
# Processing page 192 of 368
# Processing page 193 of 368
# Processing page 194 of 368
# Processing page 195 of 368
# Processing page 196 of 368
# Processing page 197 of 368
# Processing page 198 of 368
# Processing page 199 of 368
# Processing page 200 of 368
# Processing page 201 of 368
# Processing page 202 of 368
# Processing page 203 of 368
# Processing page 204 of 368
# Processing page 205 of 368
# Processing page 206 of 368
# Processing page 207 of 368
# Processing page 208 of 368
# Processing page 209 of 368
# Processing page 210 of 368
# Processing page 211 of 368
# Processing page 212 of 368
# Processing page 213 of 368
# Processing page 214 of 368
# Processing page 215 of 368
# Processing page 216 of 368
# Processing page 217 of 368
# Processing page 218 of 368
# Processing page 219 of 368
# Processing page 220 of 368
# Processing page 221 of 368
# Processing page 222 of 368
# Processing page 223 of 368
# Processing page 224 of 368
# Processing page 225 of 368
# Processing page 226 of 368
# Processing page 227 of 368
# Processing page 228 of 368
# Processing page 229 of 368
# Processing page 230 of 368
# Processing page 231 of 368
# Processing page 232 of 368
# Processing page 233 of 368
# Processing page 234 of 368
# Processing page 235 of 368
# Processing page 236 of 368
# Processing page 237 of 368
# Processing page 238 of 368
# Processing page 239 of 368
# Processing page 240 of 368
# Processing page 241 of 368
# Processing page 242 of 368
# Processing page 243 of 368
# Processing page 244 of 368
# Processing page 245 of 368
# Processing page 246 of 368
# Processing page 247 of 368
# Processing page 248 of 368
# Processing page 249 of 368
# Processing page 250 of 368
# Processing page 251 of 368
# Processing page 252 of 368
# Processing page 253 of 368
# Processing page 254 of 368
# Processing page 255 of 368
# Processing page 256 of 368
# Processing page 257 of 368
# Processing page 258 of 368
# Processing page 259 of 368
# Processing page 260 of 368
# Processing page 261 of 368
# Processing page 262 of 368
# Processing page 263 of 368
# Processing page 264 of 368
# Processing page 265 of 368
# Processing page 266 of 368
# Processing page 267 of 368
# Processing page 268 of 368
# Processing page 269 of 368
# Processing page 270 of 368
# Processing page 271 of 368
# Processing page 272 of 368
# Processing page 273 of 368
# Processing page 274 of 368
# Processing page 275 of 368
# Processing page 276 of 368
# Processing page 277 of 368
# Processing page 278 of 368
# Processing page 279 of 368
# Processing page 280 of 368
# Processing page 281 of 368
# Processing page 282 of 368
# Processing page 283 of 368
# Processing page 284 of 368
# Processing page 285 of 368
# Processing page 286 of 368
# Processing page 287 of 368
# Processing page 288 of 368
# Processing page 289 of 368
# Processing page 290 of 368
# Processing page 291 of 368
# Processing page 292 of 368
# Processing page 293 of 368
# Processing page 294 of 368
# Processing page 295 of 368
# Processing page 296 of 368
# Processing page 297 of 368
# Processing page 298 of 368
# Processing page 299 of 368
# Processing page 300 of 368
# Processing page 301 of 368
# Processing page 302 of 368
# Processing page 303 of 368
# Processing page 304 of 368
# Processing page 305 of 368
# Processing page 306 of 368
# Processing page 307 of 368
# Processing page 308 of 368
# Processing page 309 of 368
# Processing page 310 of 368
# Processing page 311 of 368
# Processing page 312 of 368
# Processing page 313 of 368
# Processing page 314 of 368
# Processing page 315 of 368
# Processing page 316 of 368
# Processing page 317 of 368
# Processing page 318 of 368
# Processing page 319 of 368
# Processing page 320 of 368
# Processing page 321 of 368
# Processing page 322 of 368
# Processing page 323 of 368
# Processing page 324 of 368
# Processing page 325 of 368
# Processing page 326 of 368
# Processing page 327 of 368
# Processing page 328 of 368
# Processing page 329 of 368
# Processing page 330 of 368
# Processing page 331 of 368
# Processing page 332 of 368
# Processing page 333 of 368
# Processing page 334 of 368
# Processing page 335 of 368
# Processing page 336 of 368
# Processing page 337 of 368
# Processing page 338 of 368
# Processing page 339 of 368
# Processing page 340 of 368
# Processing page 341 of 368
# Processing page 342 of 368
# Processing page 343 of 368
# Processing page 344 of 368
# Processing page 345 of 368
# Processing page 346 of 368
# Processing page 347 of 368
# Processing page 348 of 368
# Processing page 349 of 368
# Processing page 350 of 368
# Processing page 351 of 368
# Processing page 352 of 368
# Processing page 353 of 368
# Processing page 354 of 368
# Processing page 355 of 368
# Processing page 356 of 368
# Processing page 357 of 368
# Processing page 358 of 368
# Processing page 359 of 368
# Processing page 360 of 368
# Processing page 361 of 368
# Processing page 362 of 368
# Processing page 363 of 368
# Processing page 364 of 368
# Processing page 365 of 368
# Processing page 366 of 368
# Processing page 367 of 368
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Processing page 368 of 368
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# JSON output saved to: pdf_extractions\CDP_2024_Corporate_Questionnaire_Guidance_Modules_1-6_questionnaire_20250424_121631.json
#
# Extraction complete!
# Found 4493 questions and response items
