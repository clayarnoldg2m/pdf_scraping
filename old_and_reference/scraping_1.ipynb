# %%
import re
import os
import pdfplumber
import json
from collections import defaultdict

def extract_pdf_sections(pdf_path, max_pages=None):
    """
    Extract sections and tables from a PDF file.
    Sections are identified by patterns like (#.#.#)* or similar numbering formats.
    
    Args:
        pdf_path: Path to the PDF file
        max_pages: Maximum number of pages to process (None for all pages)
    """
    # Store all extracted content with page info
    all_content = []
    
    # Open the PDF with pdfplumber
    with pdfplumber.open(pdf_path) as pdf:
        # Determine how many pages to process
        total_pages = len(pdf.pages)
        pages_to_process = min(total_pages, max_pages) if max_pages is not None else total_pages
        
        print(f"Processing {pages_to_process} of {total_pages} pages")
        
        for page_num, page in enumerate(pdf.pages[:pages_to_process], 1):
            # Extract text and tables from the page
            text = page.extract_text()
            tables = extract_tables_from_page(page)
            
            # Remove footer (assuming footer is in last line)
            lines = text.split('\n')
            if len(lines) > 1:
                text = '\n'.join(lines[:-1])
            
            # Store page content
            all_content.append({
                'page_num': page_num,
                'text': text,
                'tables': tables
            })
    
    # Process content to identify sections and their tables
    return process_content_into_sections(all_content)

def extract_tables_from_page(page):
    """
    Extract tables from a page with improved cell structure detection.
    """
    try:
        # Try using built-in table extraction first
        tables = page.extract_tables()
        
        # If no tables found or tables appear malformed, try with explicit settings
        if not tables or any(len(row) == 0 for table in tables for row in table if table):
            # Try with explicit table settings
            tables = page.extract_tables(
                table_settings={
                    "vertical_strategy": "text", 
                    "horizontal_strategy": "text",
                    "keep_blank_chars": True,
                    "text_tolerance": 3,
                    "text_x_tolerance": 3,
                    "text_y_tolerance": 3,
                    "intersection_tolerance": 3
                }
            )
        
        return tables
    except Exception as e:
        print(f"Error extracting tables: {e}")
        return []

def process_content_into_sections(all_content):
    """
    Process extracted content to identify sections based on numbering pattern (#.#.#)*
    and associate them with tables.
    """
    sections = []
    # Enhanced section pattern to match numbering formats like (1.2.3) or (1.2) or (1)
    section_pattern = r'(\(\d+(?:\.\d+)*\))(.*?)(?=\(\d+(?:\.\d+)*\)|$)'
    
    # Concatenate all text first to properly detect sections that span multiple pages
    all_text = '\n'.join([page['text'] for page in all_content])
    
    # Find all section matches in the combined text
    section_matches = list(re.finditer(section_pattern, all_text, re.DOTALL))
    
    if not section_matches:
        # No sections found with the pattern, create a single section with all content
        return [{
            'description': 'Entire Document',
            'content': all_text,
            'tables': [process_table(table) for page in all_content for table in page['tables']]
        }]
    
    # Create sections based on matches
    for i, match in enumerate(section_matches):
        section_number = match.group(1).strip()
        section_desc = match.group(2).strip()
        
        # Determine section end position
        next_pos = match.end()
        if i < len(section_matches) - 1:
            next_pos = section_matches[i+1].start()
        
        # Create section
        section = {
            'number': section_number,
            'description': section_desc,
            'content': match.group(0).strip(),  # Full section text
            'tables': []
        }
        
        # Find start and end positions in the original text
        start_pos = match.start()
        end_pos = next_pos
        
        # Now iterate through pages to find tables that belong to this section
        current_pos = 0
        for page_content in all_content:
            page_text = page_content['text']
            page_tables = page_content['tables']
            
            # Calculate the position range for this page in the combined text
            page_start = current_pos
            page_end = current_pos + len(page_text)
            current_pos = page_end + 1  # +1 for the added newline when joining
            
            # Check if section overlaps with this page
            if not (end_pos < page_start or start_pos > page_end):
                # This page contains content for the current section
                for table in page_tables:
                    # Process and add table
                    processed_table = process_table(table)
                    if processed_table:  # Only add non-empty tables
                        section['tables'].append(processed_table)
        
        sections.append(section)
    
    return sections

def process_table(table):
    """
    Process and clean table data from pdfplumber.
    Returns a list of rows, where each row is a list of cell values.
    Handles multi-line text within cells.
    """
    if not table or len(table) == 0:
        return []
        
    processed_rows = []
    
    for row in table:
        # Clean row data
        processed_row = []
        for cell in row:
            if cell is None:
                processed_row.append("")
            else:
                # Replace newlines with spaces within cells
                cell_text = str(cell).strip().replace('\n', ' ')
                # Remove extra spaces
                cell_text = ' '.join(cell_text.split())
                processed_row.append(cell_text)
        
        # Skip completely empty rows
        if any(cell != "" for cell in processed_row):
            processed_rows.append(processed_row)
    
    return processed_rows

def save_output_to_json(sections, output_file):
    """Save the structured output to a JSON file."""
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(sections, f, indent=2, ensure_ascii=False)

def print_sections_summary(sections):
    """Print a summary of the extracted sections and tables."""
    print(f"Found {len(sections)} sections:")
    for i, section in enumerate(sections, 1):
        section_num = section.get('number', '')
        section_desc = section.get('description', '')
        section_desc_preview = section_desc[:50] + '...' if len(section_desc) > 50 else section_desc
        
        print(f"  {i}. {section_num} {section_desc_preview}")
        print(f"     Tables: {len(section['tables'])}")
        
        # Print table previews
        for j, table in enumerate(section['tables'], 1):
            if table and len(table) > 0:
                print(f"     Table {j}: {len(table)} rows x {len(table[0]) if table else 0} columns")
                if len(table) > 0:
                    first_row_preview = str(table[0])[:100] + '...' if len(str(table[0])) > 100 else table[0]
                    print(f"       First row: {first_row_preview}")

def debug_table_extraction(pdf_path, page_num, output_dir='debug_output'):
    """
    Debug function to visualize table extraction for a specific page.
    Creates visual output of how tables are being detected.
    """
    os.makedirs(output_dir, exist_ok=True)
    
    with pdfplumber.open(pdf_path) as pdf:
        if page_num < 1 or page_num > len(pdf.pages):
            print(f"Page number {page_num} out of range (1-{len(pdf.pages)})")
            return
        
        page = pdf.pages[page_num - 1]
        
        # Extract tables with default settings
        tables = page.extract_tables()
        
        # Create debug image
        img = page.to_image(resolution=150)
        img.draw_rects(page.extract_words())
        
        # Draw table boundaries
        for table in page.find_tables():
            rect = (table.bbox[0], table.bbox[1], table.bbox[2], table.bbox[3])
            img.draw_rect(rect, stroke='red', fill=None, stroke_width=3)
            
            # Draw cell boundaries
            for cell in table.cells:
                rect = (cell[0], cell[1], cell[2], cell[3])
                img.draw_rect(rect, stroke='blue', fill=None)
        
        # Save debug image
        output_path = os.path.join(output_dir, f"debug_page_{page_num}.png")
        img.save(output_path)
        print(f"Debug image saved to {output_path}")
        
        # Also save extracted text for comparison
        text_output_path = os.path.join(output_dir, f"text_page_{page_num}.txt")
        with open(text_output_path, 'w', encoding='utf-8') as f:
            f.write(page.extract_text())
        print(f"Page text saved to {text_output_path}")

def main():
    pdf_path = 'pdf_files\CDP_2024_Corporate_Questionnaire_Guidance_Modules_1-6.pdf'  # Replace with your PDF file path
    output_file = 'output_sections.json'
    max_pages = 10  # Process only the first 10 pages, set to None for all pages
    
    # Uncomment this line to debug table extraction on a specific page
    # debug_table_extraction(pdf_path, page_num=1)
    
    # Process the PDF
    sections = extract_pdf_sections(pdf_path, max_pages)
    save_output_to_json(sections, output_file)
    
    # Print summary to console
    print_sections_summary(sections)

if __name__ == "__main__":
    main()
# Out:
# <>:241: SyntaxWarning: invalid escape sequence '\C'
# <>:241: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\ClayArnold\AppData\Local\Temp\ipykernel_32288\1120588364.py:241: SyntaxWarning: invalid escape sequence '\C'
#   pdf_path = 'pdf_files\CDP_2024_Corporate_Questionnaire_Guidance_Modules_1-6.pdf'  # Replace with your PDF file path
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Processing 10 of 368 pages
# Error extracting tables: TableSettings.__init__() got an unexpected keyword argument 'keep_blank_chars'
# Error extracting tables: TableSettings.__init__() got an unexpected keyword argument 'keep_blank_chars'
# Error extracting tables: TableSettings.__init__() got an unexpected keyword argument 'keep_blank_chars'
# Error extracting tables: TableSettings.__init__() got an unexpected keyword argument 'keep_blank_chars'
# Error extracting tables: TableSettings.__init__() got an unexpected keyword argument 'keep_blank_chars'
# Error extracting tables: TableSettings.__init__() got an unexpected keyword argument 'keep_blank_chars'
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Found 124 sections:
#   1. (1.1) In which language are you submitting your response...
#      Tables: 0
#   2. (1.2) Select the currency used for all financial informa...
#      Tables: 0
#   3. (1.3) Provide an overview and introduction to your organ...
#      Tables: 0
#   4. (1.4) State the end date of the year for which you are r...
#      Tables: 0
#   5. (1.5) Provide details on your reporting boundary. .........
#      Tables: 0
#   6. (1.6) Does your organization have an ISIN code or anothe...
#      Tables: 0
#   7. (1.7) Select the countries/areas in which you operate. ....
#      Tables: 0
#   8. (1.8) Are you able to provide geolocation data for your ...
#      Tables: 0
#   9. (1.8.1) Please provide all available geolocation data for ...
#      Tables: 0
#   10. (1.9) What was the size of your organization based on to...
#      Tables: 0
#   11. (1.10) Which activities does your organization undertake,...
#      Tables: 0
#   12. (1.11) Are greenhouse gas emissions and/or water-related ...
#      Tables: 0
#   13. (1.12) Which part of the concrete value chain does your o...
#      Tables: 0
#   14. (1.13) In which part of the coal value chain does your or...
#      Tables: 0
#   15. (1.14) In which part of the chemicals value chain does yo...
#      Tables: 0
#   16. (1.15) Which real estate and/or construction activities d...
#      Tables: 0
#   17. (1.16) In which part of the electric utilities value chai...
#      Tables: 0
#   18. (1.16.1) For your electricity generation activities, provid...
#      Tables: 0
#   19. (1.17) In which part of the metals and mining value chain...
#      Tables: 0
#   20. (1.18) Provide details on the mining projects covered by ...
#      Tables: 0
#   21. (1.19) In which part of the oil and gas value chain does ...
#      Tables: 0
#   22. (1.20) Which parts of the steel value chain does your org...
#      Tables: 0
#   23. (1.21) For which transport modes will you be providing da...
#      Tables: 0
#   24. (1.22) Provide details on the commodities that you produc...
#      Tables: 0
#   25. (1.23) Which of the following agricultural commodities th...
#      Tables: 0
#   26. (1.24) Has your organization mapped its value chain? .......
#      Tables: 0
#   27. (1.24.1) Have you mapped where in your direct operations or...
#      Tables: 0
#   28. (1.24.2) Which commodities has your organization mapped in ...
#      Tables: 0
#   29. (2.1) How does your organization define short-, medium-,...
#      Tables: 0
#   30. (2.2) Does your organization have a process for identify...
#      Tables: 0
#   31. (2.2.1) Does your organization have a process for identify...
#      Tables: 0
#   32. (2.2.2) Provide details of your organization’s process for...
#      Tables: 0
#   33. (2.2.3) Provide mining-specific details of your organizati...
#      Tables: 0
#   34. (2.2.4) Does your organization have a process for identify...
#      Tables: 0
#   35. (2.2.5) Does your organization have a process for identify...
#      Tables: 0
#   36. (2.2.6) Provide details of your organization’s process for...
#      Tables: 0
#   37. (2.2.7) Are the interconnections between environmental dep...
#      Tables: 0
#   38. (2.2.8) Does your organization consider environmental info...
#      Tables: 0
#   39. (2.2.9) Indicate the environmental information your organi...
#      Tables: 0
#   40. (2.3) Have you identified priority locations across your...
#      Tables: 0
#   41. (2.4) How does your organization define substantive effe...
#      Tables: 0
#   42. (2.5) Does your organization identify and classify poten...
#      Tables: 0
#   43. (2.5.1) Describe how your organization minimizes the adver...
#      Tables: 0
#   44. (2.6) By river basin, what number of active and inactive...
#      Tables: 0
#   45. (2.6.1) Do you evaluate and classify the tailings dams und...
#      Tables: 0
#   46. (2.6.2) Provide details for all dams classified as 'hazard...
#      Tables: 0
#   47. (2.6.3) To manage the potential impacts to human health or...
#      Tables: 0
#   48. (3.1) Have you identified any environmental risks which ...
#      Tables: 0
#   49. (3.1.1) Provide details of the environmental risks identif...
#      Tables: 0
#   50. (3.1.2) Provide the amount and proportion of your financia...
#      Tables: 0
#   51. (3.2) Within each river basin, how many facilities are e...
#      Tables: 0
#   52. (3.3) In the reporting year, was your organization subje...
#      Tables: 0
#   53. (3.3.1) Provide the total number and financial value of al...
#      Tables: 0
#   54. (3.3.2) Provide details for all significant fines, enforce...
#      Tables: 0
#   55. (3.4) In the reporting year, was your organization subje...
#      Tables: 0
#   56. (3.4.1) Provide details for all significant fines, enforce...
#      Tables: 0
#   57. (3.5) Are any of your operations or activities regulated...
#      Tables: 0
#   58. (3.5.1) Select the carbon pricing regulations(s) which imp...
#      Tables: 0
#   59. (3.5.2) Provide details of each Emissions Trading Scheme (...
#      Tables: 0
#   60. (3.5.3) Complete the following table for each of the tax s...
#      Tables: 0
#   61. (3.5.4) What is your strategy for complying with the syste...
#      Tables: 0
#   62. (3.6) Have you identified any environmental opportunitie...
#      Tables: 0
#   63. (3.6.1) Provide details of the environmental opportunities...
#      Tables: 0
#   64. (3.6.2) Provide the amount and proportion of your financia...
#      Tables: 0
#   65. (4.1) Does your organization have a board of directors o...
#      Tables: 0
#   66. (4.1.1) Is there board-level oversight of environmental is...
#      Tables: 0
#   67. (4.1.2) Identify the positions (do not include any names) ...
#      Tables: 0
#   68. (4.2) Does your organization’s board have competency on ...
#      Tables: 0
#   69. (4.3) Is there management-level responsibility for envir...
#      Tables: 0
#   70. (4.3.1) Provide the highest senior management-level positi...
#      Tables: 0
#   71. (4.4) Does your organization have management-level compe...
#      Tables: 0
#   72. (4.5) Do you provide monetary incentives for the managem...
#      Tables: 0
#   73. (4.5.1) Provide further details on the monetary incentives...
#      Tables: 0
#   74. (4.6) Does your organization have an environmental polic...
#      Tables: 0
#   75. (4.6.1) Provide details of your environmental policies. .....
#      Tables: 0
#   76. (4.7) Does the policy framework for the portfolio activi...
#      Tables: 0
#   77. (4.7.1) Provide details of the policies which include envi...
#      Tables: 1
#      Table 1: 4 rows x 1 columns
#        First row: ['(4.8) Does your organization include covenants in financing agreements to reflect and enforce your...
#   78. (4.7.2) Provide details of your exclusion policies related...
#      Tables: 1
#      Table 1: 4 rows x 1 columns
#        First row: ['(4.8) Does your organization include covenants in financing agreements to reflect and enforce your...
#   79. (4.8) Does your organization include covenants in financ...
#      Tables: 1
#      Table 1: 4 rows x 1 columns
#        First row: ['(4.8) Does your organization include covenants in financing agreements to reflect and enforce your...
#   80. (4.8.1) Provide details of the covenants included in your ...
#      Tables: 1
#      Table 1: 4 rows x 1 columns
#        First row: ['(4.8) Does your organization include covenants in financing agreements to reflect and enforce your...
#   81. (4.9) Does your organization offer its employees a pensi...
#      Tables: 1
#      Table 1: 4 rows x 1 columns
#        First row: ['(4.8) Does your organization include covenants in financing agreements to reflect and enforce your...
#   82. (4.10) Are you a signatory or member of any environmental...
#      Tables: 1
#      Table 1: 4 rows x 1 columns
#        First row: ['(4.8) Does your organization include covenants in financing agreements to reflect and enforce your...
#   83. (4.11) In the reporting year, did your organization engag...
#      Tables: 1
#      Table 1: 4 rows x 1 columns
#        First row: ['(4.8) Does your organization include covenants in financing agreements to reflect and enforce your...
#   84. (4.11.1) On what policies, laws, or regulations that may (p...
#      Tables: 1
#      Table 1: 4 rows x 1 columns
#        First row: ['(4.8) Does your organization include covenants in financing agreements to reflect and enforce your...
#   85. (4.11.2) Provide details of your indirect engagement on pol...
#      Tables: 1
#      Table 1: 4 rows x 1 columns
#        First row: ['(4.8) Does your organization include covenants in financing agreements to reflect and enforce your...
#   86. (4.12) Have you published information about your organiza...
#      Tables: 1
#      Table 1: 4 rows x 1 columns
#        First row: ['(4.8) Does your organization include covenants in financing agreements to reflect and enforce your...
#   87. (4.12.1) Provide details on the information published about...
#      Tables: 1
#      Table 1: 4 rows x 1 columns
#        First row: ['(4.8) Does your organization include covenants in financing agreements to reflect and enforce your...
#   88. (5.1) Does your organization use scenario analysis to id...
#      Tables: 1
#      Table 1: 4 rows x 1 columns
#        First row: ['(4.8) Does your organization include covenants in financing agreements to reflect and enforce your...
#   89. (5.1.1) Provide details of the scenarios used in your orga...
#      Tables: 1
#      Table 1: 4 rows x 1 columns
#        First row: ['(4.8) Does your organization include covenants in financing agreements to reflect and enforce your...
#   90. (5.1.2) Provide details of the outcomes of your organizati...
#      Tables: 1
#      Table 1: 4 rows x 1 columns
#        First row: ['(4.8) Does your organization include covenants in financing agreements to reflect and enforce your...
#   91. (5.2) Does your organization’s strategy include a climat...
#      Tables: 1
#      Table 1: 4 rows x 1 columns
#        First row: ['(4.8) Does your organization include covenants in financing agreements to reflect and enforce your...
#   92. (5.4) In your organization’s financial accounting, do yo...
#      Tables: 1
#      Table 1: 4 rows x 1 columns
#        First row: ['(4.8) Does your organization include covenants in financing agreements to reflect and enforce your...
#   93. (5.4.1) Quantify the amount and percentage share of your s...
#      Tables: 1
#      Table 1: 4 rows x 1 columns
#        First row: ['(4.8) Does your organization include covenants in financing agreements to reflect and enforce your...
#   94. (5.4.2) Quantify the percentage share of your spending/rev...
#      Tables: 1
#      Table 1: 4 rows x 1 columns
#        First row: ['(4.8) Does your organization include covenants in financing agreements to reflect and enforce your...
#   95. (5.4.3) Provide any additional contextual and/or verificat...
#      Tables: 1
#      Table 1: 4 rows x 1 columns
#        First row: ['(4.8) Does your organization include covenants in financing agreements to reflect and enforce your...
#   96. (5.6) Break down, by fossil fuel expansion activity, you...
#      Tables: 0
#   97. (5.7) Break down, by source, your organization’s CAPEX i...
#      Tables: 0
#   98. (5.7.1) Break down your total planned CAPEX in your curren...
#      Tables: 0
#   99. (5.8) Disclose the breakeven price (US$/BOE) required fo...
#      Tables: 0
#   100. (5.9) What is the trend in your organization’s water-rel...
#      Tables: 0
#   101. (5.10) Does your organization use an internal price on en...
#      Tables: 0
#   102. (5.10.1) Provide details of your organization’s internal pr...
#      Tables: 0
#   103. (5.10.2) Provide details of your organization’s internal pr...
#      Tables: 0
#   104. (5.11) Do you engage with your value chain on environment...
#      Tables: 0
#   105. (5.11.1) Does your organization assess and classify supplie...
#      Tables: 0
#   106. (5.11.2) Does your organization prioritize which suppliers ...
#      Tables: 0
#   107. (5.11.3) Provide details of your environmental engagement s...
#      Tables: 0
#   108. (5.11.4) Provide details of your environmental engagement s...
#      Tables: 0
#   109. (5.11.5) Do your suppliers have to meet environmental requi...
#      Tables: 0
#   110. (5.11.6) Provide details of the environmental requirements ...
#      Tables: 0
#   111. (5.11.7) Provide further details of your organization’s sup...
#      Tables: 0
#   112. (5.11.8) Provide details of any environmental smallholder e...
#      Tables: 0
#   113. (5.11.9) Provide details of any environmental engagement ac...
#      Tables: 0
#   114. (5.12) Indicate any mutually beneficial environmental ini...
#      Tables: 0
#   115. (5.13) Has your organization already implemented any mutu...
#      Tables: 0
#   116. (5.13.1) Specify the CDP Supply Chain members that have pro...
#      Tables: 0
#   117. (5.14) Do your external asset managers have to meet envir...
#      Tables: 0
#   118. (5.14.1) Provide details of the environmental requirements ...
#      Tables: 0
#   119. (5.15) Does your organization exercise voting rights as a...
#      Tables: 0
#   120. (5.15.1) Provide details of your shareholder voting record ...
#      Tables: 0
#   121. (6.1) Provide details on your chosen consolidation appro...
#      Tables: 6
#      Table 1: 13 rows x 12 columns
#        First row: ['Module Overview', '', 'This module requests information about your organization’s disclosure to CD...
#      Table 2: 2 rows x 1 columns
#        First row: ['Module']
#      Table 3: 2 rows x 1 columns
#        First row: ['Sector-specific']
#      Table 4: 15 rows x 12 columns
#        First row: ['', 'Question details', '', '', '', '', '', '', '', '', '', '']
#      Table 5: 2 rows x 1 columns
#        First row: ['Requested']
#      Table 6: 5 rows x 6 columns
#        First row: ['Authoring notes', '', '', '', '', '']
#   122. (1.1) In which language are you submitting your response...
#      Tables: 11
#      Table 1: 13 rows x 12 columns
#        First row: ['Module Overview', '', 'This module requests information about your organization’s disclosure to CD...
#      Table 2: 2 rows x 1 columns
#        First row: ['Module']
#      Table 3: 2 rows x 1 columns
#        First row: ['Sector-specific']
#      Table 4: 15 rows x 12 columns
#        First row: ['', 'Question details', '', '', '', '', '', '', '', '', '', '']
#      Table 5: 2 rows x 1 columns
#        First row: ['Requested']
#      Table 6: 5 rows x 6 columns
#        First row: ['Authoring notes', '', '', '', '', '']
#      Table 7: 14 rows x 13 columns
#        First row: ['', 'Question details', '', '', '', '', '', '', '', '', '', '', '']
#      Table 8: 2 rows x 1 columns
#        First row: ['Requested']
#      Table 9: 5 rows x 6 columns
#        First row: ['Authoring notes', '', '', '', '', '']
#      Table 10: 5 rows x 5 columns
#        First row: ['', 'Question details', '', '', '']
#      Table 11: 4 rows x 6 columns
#        First row: ['1', '', '', '2', '3', '4']
#   123. (1.2) Select the currency used for all financial informa...
#      Tables: 5
#      Table 1: 14 rows x 13 columns
#        First row: ['', 'Question details', '', '', '', '', '', '', '', '', '', '', '']
#      Table 2: 2 rows x 1 columns
#        First row: ['Requested']
#      Table 3: 5 rows x 6 columns
#        First row: ['Authoring notes', '', '', '', '', '']
#      Table 4: 5 rows x 5 columns
#        First row: ['', 'Question details', '', '', '']
#      Table 5: 4 rows x 6 columns
#        First row: ['1', '', '', '2', '3', '4']
#   124. (1.3) Provide an overview and introduction to your organ...
#      Tables: 5
#      Table 1: 14 rows x 13 columns
#        First row: ['', 'Question details', '', '', '', '', '', '', '', '', '', '', '']
#      Table 2: 2 rows x 1 columns
#        First row: ['Requested']
#      Table 3: 5 rows x 6 columns
#        First row: ['Authoring notes', '', '', '', '', '']
#      Table 4: 5 rows x 5 columns
#        First row: ['', 'Question details', '', '', '']
#      Table 5: 4 rows x 6 columns
#        First row: ['1', '', '', '2', '3', '4']
